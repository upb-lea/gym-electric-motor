# %% [markdown]
# # Training an RL agent with Keras-RL2 Using a GEM Environment
#
# This notebook serves as an educational introduction to the usage of Keras-RL2 using a GEM environment. Goal of this notebook is to give an understanding of what Keras-RL2 is and how to use it to train and evaluate a Reinforcement Learning agent which is able to solve a current control problem within the GEM toolbox.

# %% [markdown]
# ## 1. Installation

# %% [markdown]
# Before you can start you need to make sure that you have installed both, gym-electric-motor and Keras-RL2. You can install both easily using pip:
#
# - ```pip install gym-electric-motor```
# - ```pip install keras-rl2```
#
# Alternatively, you can install them and their latest developer version directly from GitHub (recommended) :
#
# - https://github.com/upb-lea/gym-electric-motor
# - https://github.com/wau/keras-rl2
#
# For this notebook, the following cell will do the job:

# %%
# !pip install -q git+https://github.com/upb-lea/gym-electric-motor.git git+https://github.com/wau/keras-rl2.git

# %% [markdown]
# ## 2. Setting up a GEM Environment
#
# The basic idea behind reinforcement learning is to create a so-called agent, that should learn by itself to solve a specified task in a given environment.
# This environment gives the agent feedback on its actions and reinforces the targeted behavior.
# In this notebook, the task is to train a controller for the current control of a *permanent magnet synchronous motor* (*PMSM*).
#
# In the following, the used GEM-environment is briefly presented, but this notebook does not focus directly on the detailed usage of GEM. If you are new to the used environment and interested in finding out what it does and how to use it, you should take a look at the [GEM cookbook](https://colab.research.google.com/github/upb-lea/gym-electric-motor/blob/master/examples/example_notebooks/GEM_cookbook.ipynb).
#
# To save some space in this notebook, there is a function defined in an external python file called **getting_environment.py**. If you want to know how the environment's parameters are defined you can take a look at that file. By simply calling the **get_env()** function from the external file, you can set up an environment for a *PMSM* with discrete inputs.
#
# The basic idea of the control setup from the GEM-environment is displayed in the following figure.
#
# ![](../../docs/plots/SCML_Overview.png)
#
# The agent controls the converter who converts the supply currents to the currents flowing into the motor - for the *PMSM*: $i_{sq}$ and $i_{sd}$
#
# In the continuous case, the agent's action equals a duty cycle which will be modulated into a corresponding voltage.
#
# In the discrete case, the agent's actions denote switching states of the converter at the given instant. Here, only a discrete amount of options are available. In this notebook, for the PMSM the *discrete B6 bridge converter* with six switches is utilized per default. This converter provides a total of eight possible actions.
#
# ![](../../docs/plots/B6.svg)
#
# The motor schematic is the following:
#
#
# ![](../../docs/plots/ESBdq.svg)
#
# And the electrical ODEs for that motor are:
#
# <h3 align="center">
#
# <!-- $\frac{\mathrm{d}i_{sq}}{\mathrm{d}t} = \frac{u_{sq}-pL_d\omega_{me}i_{sd}-R_si_{sq}}{L_q}$
#
# $\frac{\mathrm{d}i_{sd}}{\mathrm{d}t} = \frac{u_{sd}-pL_q\omega_{me}i_{sq}-R_si_{sd}}{L_d}$
#
# $\frac{\mathrm{d}\epsilon_{el}}{\mathrm{d}t} = p\omega_{me}$
#  -->
#
#    $ \frac{\mathrm{d}i_{sd}}{\mathrm{d}t}=\frac{u_{sd} + p\omega_{me}L_q i_{sq} - R_s i_{sd}}{L_d} $ <br><br>
#     $\frac{\mathrm{d} i_{sq}}{\mathrm{d} t}=\frac{u_{sq} - p \omega_{me} (L_d i_{sd} + \mathit{\Psi}_p) - R_s i_{sq}}{L_q}$ <br><br>
#    $\frac{\mathrm{d}\epsilon_{el}}{\mathrm{d}t} = p\omega_{me}$
#
# </h3>
#
# The target for the agent is now to learn to control the currents. For this, a reference generator produces a trajectory that the agent has to follow.
# Therefore, it has to learn a function (policy) from given states, references and rewards to appropriate actions.
#
# For a deeper understanding of the used models behind the environment see the [documentation](https://upb-lea.github.io/gym-electric-motor/).
# Comprehensive learning material to RL is also [freely available](https://github.com/upb-lea/reinforcement_learning_course_materials).

# %%
import numpy as np
from pathlib import Path
import gym_electric_motor as gem
from gym_electric_motor.reference_generators import \
    MultipleReferenceGenerator,\
    WienerProcessReferenceGenerator
from gym_electric_motor.visualization import MotorDashboard
from gym.spaces import Discrete, Box
from gym.wrappers import FlattenObservation, TimeLimit
from gym import ObservationWrapper
# Out:
# /home/wilhelmk/tools/anaconda3/envs/tf-cpu/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class FeatureWrapper(ObservationWrapper):
    """
    Wrapper class which wraps the environment to change its observation. Serves
    the purpose to improve the agent's learning speed.
    
    It changes epsilon to cos(epsilon) and sin(epsilon). This serves the purpose
    to have the angles -pi and pi close to each other numerically without losing
    any information on the angle.
    
    Additionally, this wrapper adds a new observation i_sd**2 + i_sq**2. This should
    help the agent to easier detect incoming limit violations.
    """

    def __init__(self, env, epsilon_idx, i_sd_idx, i_sq_idx):
        """
        Changes the observation space to fit the new features
        
        Args:
            env(GEM env): GEM environment to wrap
            epsilon_idx(integer): Epsilon's index in the observation array
            i_sd_idx(integer): I_sd's index in the observation array
            i_sq_idx(integer): I_sq's index in the observation array
        """
        super(FeatureWrapper, self).__init__(env)
        self.EPSILON_IDX = epsilon_idx
        self.I_SQ_IDX = i_sq_idx
        self.I_SD_IDX = i_sd_idx
        new_low = np.concatenate((self.env.observation_space.low[
                                  :self.EPSILON_IDX], np.array([-1.]),
                                  self.env.observation_space.low[
                                  self.EPSILON_IDX:], np.array([0.])))
        new_high = np.concatenate((self.env.observation_space.high[
                                   :self.EPSILON_IDX], np.array([1.]),
                                   self.env.observation_space.high[
                                   self.EPSILON_IDX:],np.array([1.])))

        self.observation_space = Box(new_low, new_high)

    def observation(self, observation):
        """
        Gets called at each return of an observation. Adds the new features to the
        observation and removes original epsilon.
        
        """
        cos_eps = np.cos(observation[self.EPSILON_IDX] * np.pi)
        sin_eps = np.sin(observation[self.EPSILON_IDX] * np.pi)
        currents_squared = observation[self.I_SQ_IDX]**2 + observation[self.I_SD_IDX]**2
        observation = np.concatenate((observation[:self.EPSILON_IDX],
                                      np.array([cos_eps, sin_eps]),
                                      observation[self.EPSILON_IDX + 1:],
                                      np.array([currents_squared])))
        return observation

# %%
# define motor arguments
motor_parameter = dict(p=3,  # [p] = 1, nb of pole pairs
                       r_s=17.932e-3,  # [r_s] = Ohm, stator resistance
                       l_d=0.37e-3,  # [l_d] = H, d-axis inductance
                       l_q=1.2e-3,  # [l_q] = H, q-axis inductance
                       psi_p=65.65e-3,  # [psi_p] = Vs, magnetic flux of the permanent magnet
                       )
# supply voltage
u_sup = 350
# nominal and absolute state limitations
nominal_values=dict(omega=4000*2*np.pi/60,
                    i=230,
                    u=u_sup
                    )
limit_values=dict(omega=4000*2*np.pi/60,
                    i=1.5*230,
                    u=u_sup
                    )
# defining reference-generators
q_generator = WienerProcessReferenceGenerator(reference_state='i_sq')
d_generator = WienerProcessReferenceGenerator(reference_state='i_sd')
rg = MultipleReferenceGenerator([q_generator, d_generator])
# defining sampling interval
tau = 1e-5
# defining maximal episode steps
max_eps_steps = 10000


motor_initializer={'random_init': 'uniform', 'interval': [[-230, 230], [-230, 230], [-np.pi, np.pi]]}
reward_function=gem.reward_functions.WeightedSumOfErrors(
    reward_weights={'i_sq': 10, 'i_sd': 10},
    gamma=0.99,  # discount rate 
    reward_power=1)


# creating gem environment
env = gem.make(  # define a PMSM with discrete action space
    "PMSMDisc-v1",
    # visualize the results
    visualization=MotorDashboard(state_plots=['i_sq', 'i_sd'], reward_plot=True),
    # parameterize the PMSM and update limitations
    motor_parameter=motor_parameter,
    limit_values=limit_values, nominal_values=nominal_values,
    # define the random initialisation for load and motor
    load='ConstSpeedLoad',
    load_initializer={'random_init': 'uniform', },
    motor_initializer=motor_initializer,
    reward_function=reward_function,

    # define the duration of one sampling step
    tau=tau, u_sup=u_sup,
    # turn off terminations via limit violation, parameterize the rew-fct
    reference_generator=rg, ode_solver='euler',
)

# remove one action from the action space to help the agent speed up its training
# this can be done as both switchting states (1,1,1) and (-1,-1,-1) - which are encoded
# by action 0 and 7 - both lead to the same zero voltage vector in alpha/beta-coordinates
env.action_space = Discrete(7)

# applying wrappers
eps_idx = env.physical_system.state_names.index('epsilon')
i_sd_idx = env.physical_system.state_names.index('i_sd')
i_sq_idx = env.physical_system.state_names.index('i_sq')
env = TimeLimit(FeatureWrapper(FlattenObservation(env), 
                               eps_idx, i_sd_idx, i_sq_idx),
                max_eps_steps)

# %% [markdown]
# ## 3. Train an Agent with Keras-RL2

# %% [markdown]
# [Keras-RL2](https://github.com/wau/keras-rl2) is a widely used Python library for reinforcement learning. It compiles a collection of Reinforcement Learning algorithm implementations.
# Most of the algorithms and their extensions are readily available and are quite stable. The ease of adopting to various environments adds to its popularity.
# For currently available RL algorithms see their [documentation](https://keras-rl.readthedocs.io/en/latest/agents/overview/)

# %% [markdown]
# ### 3.1 Imports
# The environment in this control problem poses a discrete action space. Therefore, the [Deep Q-Network (DQN)](https://arxiv.org/abs/1312.5602) is a suitable agent.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory

# %% [markdown]
# ### 3.2 Parameters and Instantiation

# %% [markdown]
# For the DQN algorithm, a set of parameters has to be pre-defined.
# In particular, a multilayer perceptron (MLP) is used as function approximator within the DQN algorithm.
# Note: Although there are 8 possible actions, we ignore the last action as the voltage applied on the motor there is the same as for the first action. This effectively reduces the feature space that is to be explored and benefits training.

# %%
# Training parameters.
time_limit = True
buffer_size = 200000  # observation history size
batch_size = 25  # mini batch size sampled from history at each update step
nb_actions = env.action_space.n
window_length = 1

# construct a MLP
model = Sequential()
model.add(Flatten(input_shape=(window_length,) + env.observation_space.shape))
model.add(Dense(64, activation='relu'))  # hidden layer 1
model.add(Dense(64, activation='relu'))  # hidden layer 2
model.add(Dense(nb_actions, activation='linear'))  # output layer

# keras-rl2 objects
memory = SequentialMemory(limit=200000, window_length=window_length)
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(eps=0.2), 'eps', 1, 0.05, 0, 50000)

# %% [markdown]
# ### 3.3 Training

# %% [markdown]
# Once you've setup the environment and defined your parameters starting the training is nothing more than a one-liner. For each algorithm all you have to do is call its ```fit()``` function.
#
# The advantage of keras-RL2 is that you can see all the important parameters and their values during training phase to get an intution of learning.
# Hence, there is no need of additional callbacks.

# %%
dqn = DQNAgent(
    model=model,
    policy=policy,
    nb_actions=nb_actions,
    memory=memory,
    gamma=0.99,
    batch_size=25,
    train_interval=1,
    memory_interval=1,
    target_model_update=1000,
    nb_steps_warmup=10000,
    enable_double_dqn=True
)

dqn.compile(Adam(lr=1e-4),
            metrics=['mse']
            )

# %%
# %matplotlib notebook
history = dqn.fit(env,
            nb_steps=100000,
            action_repetition=1,
            verbose=2,
            visualize=True,
            nb_max_episode_steps=10000,
            log_interval=1000
            )
# Out:
# Training for 100000 steps ...
# WARNING:tensorflow:From /home/wilhelmk/tools/anaconda3/envs/tf-cpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# <img src="data:image/png;base64,..." width="640">
#   1071/100000: episode: 1, duration: 1.541s, episode steps: 1071, steps per second: 695, episode reward: -5681.995, mean reward: -5.305 [-2000.000, -0.581], mean action: 2.986 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   1224/100000: episode: 2, duration: 0.115s, episode steps: 153, steps per second: 1336, episode reward: -2484.636, mean reward: -16.239 [-2000.000, -0.618], mean action: 2.817 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   1509/100000: episode: 3, duration: 0.234s, episode steps: 285, steps per second: 1216, episode reward: -3035.728, mean reward: -10.652 [-2000.000, -1.583], mean action: 3.025 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   2889/100000: episode: 4, duration: 1.330s, episode steps: 1380, steps per second: 1037, episode reward: -7204.951, mean reward: -5.221 [-2000.000, -0.148], mean action: 2.933 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   2966/100000: episode: 5, duration: 0.065s, episode steps:  77, steps per second: 1181, episode reward: -2404.771, mean reward: -31.231 [-2000.000, -4.090], mean action: 2.675 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   3131/100000: episode: 6, duration: 0.133s, episode steps: 165, steps per second: 1238, episode reward: -2363.593, mean reward: -14.325 [-2000.000, -0.826], mean action: 2.855 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   3414/100000: episode: 7, duration: 0.240s, episode steps: 283, steps per second: 1177, episode reward: -3059.102, mean reward: -10.810 [-2000.000, -1.582], mean action: 3.042 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   4714/100000: episode: 8, duration: 1.184s, episode steps: 1300, steps per second: 1098, episode reward: -6413.097, mean reward: -4.933 [-2000.000, -0.182], mean action: 3.037 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   4878/100000: episode: 9, duration: 0.132s, episode steps: 164, steps per second: 1244, episode reward: -2655.505, mean reward: -16.192 [-2000.000, -0.182], mean action: 2.963 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   6731/100000: episode: 10, duration: 1.682s, episode steps: 1853, steps per second: 1102, episode reward: -8132.135, mean reward: -4.389 [-2000.000, -0.069], mean action: 2.998 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   7251/100000: episode: 11, duration: 0.433s, episode steps: 520, steps per second: 1202, episode reward: -4931.979, mean reward: -9.485 [-2000.000, -1.421], mean action: 2.913 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   7927/100000: episode: 12, duration: 0.543s, episode steps: 676, steps per second: 1245, episode reward: -4549.053, mean reward: -6.729 [-2000.000, -0.688], mean action: 2.883 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   8474/100000: episode: 13, duration: 0.437s, episode steps: 547, steps per second: 1252, episode reward: -3427.139, mean reward: -6.265 [-2000.000, -0.169], mean action: 3.082 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   9146/100000: episode: 14, duration: 0.539s, episode steps: 672, steps per second: 1247, episode reward: -4466.046, mean reward: -6.646 [-2000.000, -0.389], mean action: 2.716 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   9266/100000: episode: 15, duration: 0.096s, episode steps: 120, steps per second: 1253, episode reward: -2509.662, mean reward: -20.914 [-2000.000, -1.519], mean action: 3.217 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   9345/100000: episode: 16, duration: 0.067s, episode steps:  79, steps per second: 1174, episode reward: -2413.325, mean reward: -30.548 [-2000.000, -2.819], mean action: 3.177 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#   9424/100000: episode: 17, duration: 0.074s, episode steps:  79, steps per second: 1066, episode reward: -2292.458, mean reward: -29.018 [-2000.000, -1.839], mean action: 2.823 [0.000, 6.000],  loss: --, mse: --, mean_q: --, mean_eps: --
#  10136/100000: episode: 18, duration: 1.609s, episode steps: 712, steps per second: 443, episode reward: -3268.977, mean reward: -4.591 [-2000.000, -0.299], mean action: 2.903 [0.000, 6.000],  loss: 4745.992097, mse: 1356.054479, mean_q: 0.175844, mean_eps: 0.808708
#  10222/100000: episode: 19, duration: 0.521s, episode steps:  86, steps per second: 165, episode reward: -2407.743, mean reward: -27.997 [-2000.000, -3.356], mean action: 2.384 [0.000, 6.000],  loss: 2795.800518, mse: 798.894239, mean_q: 0.058199, mean_eps: 0.806609
#  10832/100000: episode: 20, duration: 3.626s, episode steps: 610, steps per second: 168, episode reward: -5338.433, mean reward: -8.752 [-2000.000, -1.749], mean action: 2.982 [0.000, 6.000],  loss: 4330.779294, mse: 1237.646993, mean_q: -0.155219, mean_eps: 0.799997
#  10921/100000: episode: 21, duration: 0.634s, episode steps:  89, steps per second: 140, episode reward: -2339.261, mean reward: -26.284 [-2000.000, -1.596], mean action: 2.865 [0.000, 6.000],  loss: 8984.518888, mse: 2567.573004, mean_q: -0.389455, mean_eps: 0.793356
#  11157/100000: episode: 22, duration: 1.556s, episode steps: 236, steps per second: 152, episode reward: -2797.002, mean reward: -11.852 [-2000.000, -1.884], mean action: 2.801 [0.000, 6.000],  loss: 3054.186233, mse: 873.428990, mean_q: -0.501868, mean_eps: 0.790269
#  11199/100000: episode: 23, duration: 0.264s, episode steps:  42, steps per second: 159, episode reward: -2204.162, mean reward: -52.480 [-2000.000, -3.147], mean action: 3.405 [0.000, 6.000],  loss: 5712.953484, mse: 1633.324177, mean_q: -0.612989, mean_eps: 0.787628
#  11278/100000: episode: 24, duration: 0.491s, episode steps:  79, steps per second: 161, episode reward: -2259.712, mean reward: -28.604 [-2000.000, -1.099], mean action: 2.873 [0.000, 6.000],  loss: 4051.166665, mse: 1158.671328, mean_q: -0.670278, mean_eps: 0.786478
#  11524/100000: episode: 25, duration: 1.538s, episode steps: 246, steps per second: 160, episode reward: -2782.089, mean reward: -11.309 [-2000.000, -0.520], mean action: 2.825 [0.000, 6.000],  loss: 3901.938998, mse: 1116.524886, mean_q: -0.856754, mean_eps: 0.783390
#  11616/100000: episode: 26, duration: 0.616s, episode steps:  92, steps per second: 149, episode reward: -2466.746, mean reward: -26.812 [-2000.000, -1.805], mean action: 3.174 [0.000, 6.000],  loss: 5212.309646, mse: 1491.470336, mean_q: -1.044576, mean_eps: 0.780179
#  11966/100000: episode: 27, duration: 2.196s, episode steps: 350, steps per second: 159, episode reward: -2765.551, mean reward: -7.902 [-2000.000, -0.127], mean action: 3.034 [0.000, 6.000],  loss: 4565.485422, mse: 1307.849097, mean_q: -1.356989, mean_eps: 0.775980
#  11998/100000: episode: 28, duration: 0.196s, episode steps:  32, steps per second: 163, episode reward: -2176.376, mean reward: -68.012 [-2000.000, -4.289], mean action: 1.969 [0.000, 6.000],  loss: 3.745269, mse: 5.466228, mean_q: -1.583379, mean_eps: 0.772352
#  12232/100000: episode: 29, duration: 1.440s, episode steps: 234, steps per second: 163, episode reward: -2608.637, mean reward: -11.148 [-2000.000, -0.837], mean action: 2.880 [0.000, 6.000],  loss: 5119.520422, mse: 1468.146492, mean_q: -1.775065, mean_eps: 0.769824
#  12311/100000: episode: 30, duration: 0.486s, episode steps:  79, steps per second: 163, episode reward: -2336.569, mean reward: -29.577 [-2000.000, -2.432], mean action: 2.722 [0.000, 6.000],  loss: 9090.690937, mse: 2604.463986, mean_q: -2.115375, mean_eps: 0.766851
#  12827/100000: episode: 31, duration: 3.177s, episode steps: 516, steps per second: 162, episode reward: -4616.100, mean reward: -8.946 [-2000.000, -0.231], mean action: 2.853 [0.000, 6.000],  loss: 5251.033107, mse: 1511.944045, mean_q: -2.887535, mean_eps: 0.761199
#  13034/100000: episode: 32, duration: 1.276s, episode steps: 207, steps per second: 162, episode reward: -2606.617, mean reward: -12.592 [-2000.000, -1.246], mean action: 3.623 [0.000, 6.000],  loss: 4614.620192, mse: 1335.313762, mean_q: -3.629766, mean_eps: 0.754330
#  13458/100000: episode: 33, duration: 2.583s, episode steps: 424, steps per second: 164, episode reward: -3674.151, mean reward: -8.665 [-2000.000, -0.236], mean action: 3.715 [0.000, 6.000],  loss: 5063.572434, mse: 1472.585763, mean_q: -4.527328, mean_eps: 0.748336
#  14123/100000: episode: 34, duration: 4.165s, episode steps: 665, steps per second: 160, episode reward: -3890.711, mean reward: -5.851 [-2000.000, -0.288], mean action: 3.495 [0.000, 6.000],  loss: 3697.737693, mse: 1100.509215, mean_q: -5.971015, mean_eps: 0.737990
#  14598/100000: episode: 35, duration: 2.909s, episode steps: 475, steps per second: 163, episode reward: -4109.260, mean reward: -8.651 [-2000.000, -0.232], mean action: 3.701 [0.000, 6.000],  loss: 5158.581902, mse: 1549.870762, mean_q: -8.167042, mean_eps: 0.727160
#  15008/100000: episode: 36, duration: 2.482s, episode steps: 410, steps per second: 165, episode reward: -3724.993, mean reward: -9.085 [-2000.000, -1.292], mean action: 3.795 [0.000, 6.000],  loss: 5190.577190, mse: 1593.577396, mean_q: -9.736327, mean_eps: 0.718753
#  15511/100000: episode: 37, duration: 3.081s, episode steps: 503, steps per second: 163, episode reward: -4265.081, mean reward: -8.479 [-2000.000, -2.818], mean action: 3.877 [0.000, 6.000],  loss: 3596.237364, mse: 1172.122355, mean_q: -11.181805, mean_eps: 0.710079
#  15781/100000: episode: 38, duration: 1.758s, episode steps: 270, steps per second: 154, episode reward: -3061.102, mean reward: -11.337 [-2000.000, -1.881], mean action: 3.741 [0.000, 6.000],  loss: 2614.398867, mse: 929.136741, mean_q: -12.712166, mean_eps: 0.702735
#  15835/100000: episode: 39, duration: 0.317s, episode steps:  54, steps per second: 171, episode reward: -2287.275, mean reward: -42.357 [-2000.000, -5.028], mean action: 3.741 [0.000, 6.000],  loss: 5812.107319, mse: 1857.114206, mean_q: -13.284845, mean_eps: 0.699658
#  15890/100000: episode: 40, duration: 0.380s, episode steps:  55, steps per second: 145, episode reward: -2313.124, mean reward: -42.057 [-2000.000, -3.767], mean action: 4.036 [0.000, 6.000],  loss: 4280.100191, mse: 1426.014862, mean_q: -13.558875, mean_eps: 0.698622
#  15941/100000: episode: 41, duration: 0.377s, episode steps:  51, steps per second: 135, episode reward: -2330.329, mean reward: -45.693 [-2000.000, -5.409], mean action: 3.745 [0.000, 6.000],  loss: 6147.538378, mse: 1968.016356, mean_q: -13.754020, mean_eps: 0.697615
#  16070/100000: episode: 42, duration: 0.831s, episode steps: 129, steps per second: 155, episode reward: -2470.884, mean reward: -19.154 [-2000.000, -1.893], mean action: 3.922 [0.000, 6.000],  loss: 3047.288480, mse: 1087.702496, mean_q: -14.075034, mean_eps: 0.695905
#  16400/100000: episode: 43, duration: 2.091s, episode steps: 330, steps per second: 158, episode reward: -2954.173, mean reward: -8.952 [-2000.000, -0.137], mean action: 3.882 [0.000, 6.000],  loss: 4031.302997, mse: 1404.065403, mean_q: -15.361341, mean_eps: 0.691545
#  16469/100000: episode: 44, duration: 0.470s, episode steps:  69, steps per second: 147, episode reward: -2379.299, mean reward: -34.483 [-2000.000, -4.052], mean action: 3.623 [0.000, 6.000],  loss: 10153.992684, mse: 3194.173992, mean_q: -16.618231, mean_eps: 0.687754
#  16918/100000: episode: 45, duration: 2.787s, episode steps: 449, steps per second: 161, episode reward: -3498.520, mean reward: -7.792 [-2000.000, -0.614], mean action: 3.768 [0.000, 6.000],  loss: 4684.130344, mse: 1682.856235, mean_q: -18.172674, mean_eps: 0.682833
#  17161/100000: episode: 46, duration: 1.533s, episode steps: 243, steps per second: 159, episode reward: -2949.355, mean reward: -12.137 [-2000.000, -0.998], mean action: 3.848 [0.000, 6.000],  loss: 4800.190086, mse: 1785.791605, mean_q: -19.808103, mean_eps: 0.676259
#  17215/100000: episode: 47, duration: 0.353s, episode steps:  54, steps per second: 153, episode reward: -2184.574, mean reward: -40.455 [-2000.000, -2.118], mean action: 3.611 [0.000, 6.000],  loss: 2872.079008, mse: 1265.704418, mean_q: -20.436887, mean_eps: 0.673438
#  17297/100000: episode: 48, duration: 0.550s, episode steps:  82, steps per second: 149, episode reward: -2416.935, mean reward: -29.475 [-2000.000, -3.237], mean action: 3.598 [0.000, 6.000],  loss: 950.765115, mse: 723.841426, mean_q: -20.553414, mean_eps: 0.672146
#  17753/100000: episode: 49, duration: 2.888s, episode steps: 456, steps per second: 158, episode reward: -3995.015, mean reward: -8.761 [-2000.000, -0.879], mean action: 3.912 [0.000, 6.000],  loss: 5434.166517, mse: 2065.098118, mean_q: -22.148009, mean_eps: 0.667034
#  18196/100000: episode: 50, duration: 2.779s, episode steps: 443, steps per second: 159, episode reward: -3554.988, mean reward: -8.025 [-2000.000, -1.583], mean action: 3.526 [0.000, 6.000],  loss: 4879.136424, mse: 2036.561344, mean_q: -25.221982, mean_eps: 0.658494
#  18385/100000: episode: 51, duration: 1.173s, episode steps: 189, steps per second: 161, episode reward: -3103.169, mean reward: -16.419 [-2000.000, -3.316], mean action: 2.820 [0.000, 6.000],  loss: 6082.073251, mse: 2509.716531, mean_q: -28.001278, mean_eps: 0.652490
#  18898/100000: episode: 52, duration: 3.151s, episode steps: 513, steps per second: 163, episode reward: -3184.487, mean reward: -6.208 [-2000.000, -1.198], mean action: 3.004 [0.000, 6.000],  loss: 6118.469374, mse: 2678.650693, mean_q: -30.525860, mean_eps: 0.645821
#  19049/100000: episode: 53, duration: 0.936s, episode steps: 151, steps per second: 161, episode reward: -2462.238, mean reward: -16.306 [-2000.000, -0.657], mean action: 2.689 [0.000, 6.000],  loss: 5070.701608, mse: 2467.365841, mean_q: -31.599905, mean_eps: 0.639513
#  19749/100000: episode: 54, duration: 4.264s, episode steps: 700, steps per second: 164, episode reward: -3853.982, mean reward: -5.506 [-2000.000, -0.536], mean action: 2.846 [0.000, 6.000],  loss: 6177.643171, mse: 3018.013935, mean_q: -34.993981, mean_eps: 0.631429
#  19809/100000: episode: 55, duration: 0.400s, episode steps:  60, steps per second: 150, episode reward: -2333.911, mean reward: -38.899 [-2000.000, -3.430], mean action: 2.600 [0.000, 6.000],  loss: 5034.377644, mse: 2892.297158, mean_q: -37.248693, mean_eps: 0.624209
#  19867/100000: episode: 56, duration: 0.380s, episode steps:  58, steps per second: 153, episode reward: -2274.868, mean reward: -39.222 [-2000.000, -2.152], mean action: 2.552 [0.000, 6.000],  loss: 1327.604522, mse: 1813.648214, mean_q: -36.897737, mean_eps: 0.623088
#  20226/100000: episode: 57, duration: 2.255s, episode steps: 359, steps per second: 159, episode reward: -3363.765, mean reward: -9.370 [-2000.000, -0.611], mean action: 2.624 [0.000, 6.000],  loss: 6112.030159, mse: 3267.824451, mean_q: -37.823354, mean_eps: 0.619126
#  20301/100000: episode: 58, duration: 0.459s, episode steps:  75, steps per second: 163, episode reward: -2278.098, mean reward: -30.375 [-2000.000, -2.138], mean action: 2.667 [0.000, 6.000],  loss: 7059.223289, mse: 3620.147144, mean_q: -38.980977, mean_eps: 0.615003
#  20471/100000: episode: 59, duration: 1.067s, episode steps: 170, steps per second: 159, episode reward: -2451.867, mean reward: -14.423 [-2000.000, -0.198], mean action: 2.600 [0.000, 6.000],  loss: 4019.028956, mse: 2821.970863, mean_q: -39.856104, mean_eps: 0.612676
#  20999/100000: episode: 60, duration: 3.345s, episode steps: 528, steps per second: 158, episode reward: -3113.628, mean reward: -5.897 [-2000.000, -0.216], mean action: 2.970 [0.000, 6.000],  loss: 6540.661106, mse: 3704.527296, mean_q: -43.320387, mean_eps: 0.606045
#  22290/100000: episode: 61, duration: 8.186s, episode steps: 1291, steps per second: 158, episode reward: -7139.297, mean reward: -5.530 [-2000.000, -1.386], mean action: 2.761 [0.000, 6.000],  loss: 4608.624783, mse: 3731.049534, mean_q: -50.080731, mean_eps: 0.588764
#  22376/100000: episode: 62, duration: 0.549s, episode steps:  86, steps per second: 157, episode reward: -2167.861, mean reward: -25.208 [-2000.000, -0.890], mean action: 3.698 [0.000, 6.000],  loss: 2512.321492, mse: 3558.075070, mean_q: -54.385673, mean_eps: 0.575682
#  22497/100000: episode: 63, duration: 0.738s, episode steps: 121, steps per second: 164, episode reward: -2588.110, mean reward: -21.389 [-2000.000, -2.385], mean action: 3.314 [0.000, 6.000],  loss: 6079.439203, mse: 4727.323157, mean_q: -55.524024, mean_eps: 0.573716
#  22945/100000: episode: 64, duration: 2.729s, episode steps: 448, steps per second: 164, episode reward: -3607.049, mean reward: -8.051 [-2000.000, -0.915], mean action: 3.056 [0.000, 6.000],  loss: 5543.640663, mse: 4782.854632, mean_q: -56.971045, mean_eps: 0.568311
#  23341/100000: episode: 65, duration: 2.481s, episode steps: 396, steps per second: 160, episode reward: -3610.436, mean reward: -9.117 [-2000.000, -1.116], mean action: 3.179 [0.000, 6.000],  loss: 4798.767878, mse: 4851.498363, mean_q: -59.477091, mean_eps: 0.560292
#  23358/100000: episode: 66, duration: 0.110s, episode steps:  17, steps per second: 155, episode reward: -2093.206, mean reward: -123.130 [-2000.000, -5.400], mean action: 3.529 [1.000, 6.000],  loss: 4176.657281, mse: 5043.947668, mean_q: -62.907804, mean_eps: 0.556369
#  24044/100000: episode: 67, duration: 4.299s, episode steps: 686, steps per second: 160, episode reward: -4235.027, mean reward: -6.174 [-2000.000, -0.918], mean action: 3.313 [0.000, 6.000],  loss: 4329.305883, mse: 5057.466625, mean_q: -62.466402, mean_eps: 0.549691
#  25175/100000: episode: 68, duration: 7.278s, episode steps: 1131, steps per second: 155, episode reward: -7037.887, mean reward: -6.223 [-2000.000, -0.022], mean action: 2.418 [0.000, 6.000],  loss: 5460.037417, mse: 6231.435967, mean_q: -68.599211, mean_eps: 0.532429
#  25320/100000: episode: 69, duration: 0.931s, episode steps: 145, steps per second: 156, episode reward: -2944.872, mean reward: -20.309 [-2000.000, -2.807], mean action: 1.407 [0.000, 6.000],  loss: 2901.661478, mse: 6176.694972, mean_q: -73.389732, mean_eps: 0.520307
#  25720/100000: episode: 70, duration: 2.488s, episode steps: 400, steps per second: 161, episode reward: -3881.185, mean reward: -9.703 [-2000.000, -0.807], mean action: 1.452 [0.000, 6.000],  loss: 5297.222494, mse: 7114.885258, mean_q: -75.230035, mean_eps: 0.515130
#  28591/100000: episode: 71, duration: 18.799s, episode steps: 2871, steps per second: 153, episode reward: -12060.069, mean reward: -4.201 [-2000.000, -0.058], mean action: 1.902 [0.000, 6.000],  loss: 4486.260969, mse: 8298.793950, mean_q: -83.534728, mean_eps: 0.484055
#  28620/100000: episode: 72, duration: 0.192s, episode steps:  29, steps per second: 151, episode reward: -2181.063, mean reward: -75.209 [-2000.000, -5.884], mean action: 2.828 [0.000, 6.000],  loss: 7243.913756, mse: 9912.676674, mean_q: -89.010134, mean_eps: 0.456505
#  29898/100000: episode: 73, duration: 8.795s, episode steps: 1278, steps per second: 145, episode reward: -7111.218, mean reward: -5.564 [-2000.000, -0.390], mean action: 1.664 [0.000, 6.000],  loss: 3584.456884, mse: 9670.762563, mean_q: -93.639781, mean_eps: 0.444089
#  30498/100000: episode: 74, duration: 3.853s, episode steps: 600, steps per second: 156, episode reward: -4126.675, mean reward: -6.878 [-2000.000, -1.222], mean action: 1.307 [0.000, 6.000],  loss: 4060.371334, mse: 10756.636453, mean_q: -97.041950, mean_eps: 0.426248
#  30536/100000: episode: 75, duration: 0.237s, episode steps:  38, steps per second: 160, episode reward: -2195.469, mean reward: -57.776 [-2000.000, -4.607], mean action: 1.316 [0.000, 6.000],  loss: 1888.390861, mse: 10321.779605, mean_q: -98.165698, mean_eps: 0.420187
#  30704/100000: episode: 76, duration: 1.113s, episode steps: 168, steps per second: 151, episode reward: -2731.750, mean reward: -16.260 [-2000.000, -2.345], mean action: 1.393 [0.000, 6.000],  loss: 2768.668147, mse: 10544.836266, mean_q: -97.758157, mean_eps: 0.418230
#  30793/100000: episode: 77, duration: 0.671s, episode steps:  89, steps per second: 133, episode reward: -2311.863, mean reward: -25.976 [-2000.000, -1.880], mean action: 1.236 [0.000, 6.000],  loss: 2223.912074, mse: 10429.548384, mean_q: -98.327397, mean_eps: 0.415788
#  31351/100000: episode: 78, duration: 3.785s, episode steps: 558, steps per second: 147, episode reward: -3882.197, mean reward: -6.957 [-2000.000, -0.856], mean action: 1.165 [0.000, 6.000],  loss: 5220.152453, mse: 11796.434141, mean_q: -99.831665, mean_eps: 0.409642
#  33609/100000: episode: 79, duration: 15.320s, episode steps: 2258, steps per second: 147, episode reward: -10063.845, mean reward: -4.457 [-2000.000, -0.149], mean action: 1.229 [0.000, 6.000],  loss: 3605.436487, mse: 11845.402472, mean_q: -101.843951, mean_eps: 0.382890
#  33760/100000: episode: 80, duration: 1.063s, episode steps: 151, steps per second: 142, episode reward: -2748.667, mean reward: -18.203 [-2000.000, -0.875], mean action: 1.079 [0.000, 6.000],  loss: 4420.226711, mse: 12994.007399, mean_q: -106.041379, mean_eps: 0.360004
#  33856/100000: episode: 81, duration: 0.687s, episode steps:  96, steps per second: 140, episode reward: -2492.205, mean reward: -25.960 [-2000.000, -2.716], mean action: 1.010 [0.000, 6.000],  loss: 3377.897767, mse: 12799.455790, mean_q: -105.687731, mean_eps: 0.357658
#  34011/100000: episode: 82, duration: 0.976s, episode steps: 155, steps per second: 159, episode reward: -2573.820, mean reward: -16.605 [-2000.000, -2.378], mean action: 1.148 [0.000, 6.000],  loss: 3035.686991, mse: 12440.943454, mean_q: -105.014267, mean_eps: 0.355273
#  34048/100000: episode: 83, duration: 0.247s, episode steps:  37, steps per second: 150, episode reward: -2210.731, mean reward: -59.749 [-2000.000, -3.966], mean action: 0.865 [0.000, 5.000],  loss: 1808.415942, mse: 12198.037347, mean_q: -105.791463, mean_eps: 0.353449
#  34100/100000: episode: 84, duration: 0.353s, episode steps:  52, steps per second: 147, episode reward: -2335.690, mean reward: -44.917 [-2000.000, -5.665], mean action: 1.019 [0.000, 6.000],  loss: 6317.673845, mse: 13712.495418, mean_q: -107.174680, mean_eps: 0.352604
#  34125/100000: episode: 85, duration: 0.159s, episode steps:  25, steps per second: 157, episode reward: -2141.800, mean reward: -85.672 [-2000.000, -4.997], mean action: 1.520 [0.000, 6.000],  loss: 18.209399, mse: 11745.286094, mean_q: -106.113470, mean_eps: 0.351872
#  40818/100000: episode: 86, duration: 45.014s, episode steps: 6693, steps per second: 149, episode reward: -33649.362, mean reward: -5.028 [-2000.000, -0.023], mean action: 0.970 [0.000, 6.000],  loss: 3462.829004, mse: 15358.171606, mean_q: -118.257641, mean_eps: 0.288051
#  41090/100000: episode: 87, duration: 1.843s, episode steps: 272, steps per second: 148, episode reward: -3105.696, mean reward: -11.418 [-2000.000, -1.753], mean action: 0.511 [0.000, 6.000],  loss: 4396.357151, mse: 19419.933640, mean_q: -131.949732, mean_eps: 0.221884
#  41244/100000: episode: 88, duration: 1.045s, episode steps: 154, steps per second: 147, episode reward: -2670.806, mean reward: -17.343 [-2000.000, -2.831], mean action: 0.968 [0.000, 6.000],  loss: 7270.453202, mse: 21607.707412, mean_q: -136.799989, mean_eps: 0.217837
#  41442/100000: episode: 89, duration: 1.333s, episode steps: 198, steps per second: 149, episode reward: -2619.420, mean reward: -13.229 [-2000.000, -1.322], mean action: 0.571 [0.000, 6.000],  loss: 963.326339, mse: 19711.118337, mean_q: -135.334326, mean_eps: 0.214493
#  41644/100000: episode: 90, duration: 1.365s, episode steps: 202, steps per second: 148, episode reward: -2883.500, mean reward: -14.275 [-2000.000, -3.370], mean action: 0.594 [0.000, 6.000],  loss: 3364.436010, mse: 19469.745291, mean_q: -133.115466, mean_eps: 0.210693
#  41716/100000: episode: 91, duration: 0.548s, episode steps:  72, steps per second: 131, episode reward: -2391.576, mean reward: -33.216 [-2000.000, -4.911], mean action: 0.528 [0.000, 6.000],  loss: 915.473051, mse: 20115.441094, mean_q: -139.141428, mean_eps: 0.208090
#  41755/100000: episode: 92, duration: 0.260s, episode steps:  39, steps per second: 150, episode reward: -2207.290, mean reward: -56.597 [-2000.000, -4.352], mean action: 0.641 [0.000, 5.000],  loss: 1562.690028, mse: 20122.458959, mean_q: -138.627792, mean_eps: 0.207035
#  41889/100000: episode: 93, duration: 0.987s, episode steps: 134, steps per second: 136, episode reward: -2494.346, mean reward: -18.615 [-2000.000, -1.886], mean action: 0.806 [0.000, 6.000],  loss: 3613.039232, mse: 20170.708059, mean_q: -136.543403, mean_eps: 0.205392
#  42234/100000: episode: 94, duration: 2.291s, episode steps: 345, steps per second: 151, episode reward: -2784.191, mean reward: -8.070 [-2000.000, -0.026], mean action: 0.719 [0.000, 6.000],  loss: 2979.454572, mse: 20274.430055, mean_q: -137.438640, mean_eps: 0.200841
#  42359/100000: episode: 95, duration: 0.832s, episode steps: 125, steps per second: 150, episode reward: -2730.328, mean reward: -21.843 [-2000.000, -3.606], mean action: 0.568 [0.000, 6.000],  loss: 3931.872000, mse: 21295.337734, mean_q: -140.884396, mean_eps: 0.196376
#  43030/100000: episode: 96, duration: 4.470s, episode steps: 671, steps per second: 150, episode reward: -4801.211, mean reward: -7.155 [-2000.000, -1.687], mean action: 1.186 [0.000, 6.000],  loss: 4077.910584, mse: 21573.836437, mean_q: -141.094235, mean_eps: 0.188814
#  46398/100000: episode: 97, duration: 22.678s, episode steps: 3368, steps per second: 149, episode reward: -13064.284, mean reward: -3.879 [-2000.000, -0.069], mean action: 0.798 [0.000, 6.000],  loss: 3646.422494, mse: 24331.233789, mean_q: -149.935765, mean_eps: 0.150444
#  47625/100000: episode: 98, duration: 8.319s, episode steps: 1227, steps per second: 147, episode reward: -5258.998, mean reward: -4.286 [-2000.000, -0.974], mean action: 0.691 [0.000, 6.000],  loss: 2979.193722, mse: 27627.065173, mean_q: -161.603234, mean_eps: 0.106791
#  47860/100000: episode: 99, duration: 1.565s, episode steps: 235, steps per second: 150, episode reward: -2893.419, mean reward: -12.312 [-2000.000, -1.604], mean action: 1.209 [0.000, 6.000],  loss: 2537.503636, mse: 27862.983968, mean_q: -163.464684, mean_eps: 0.092902
#  48279/100000: episode: 100, duration: 2.734s, episode steps: 419, steps per second: 153, episode reward: -2935.754, mean reward: -7.007 [-2000.000, -0.129], mean action: 1.434 [0.000, 6.000],  loss: 2950.555905, mse: 28975.047176, mean_q: -166.764374, mean_eps: 0.086689
#  49931/100000: episode: 101, duration: 11.188s, episode steps: 1652, steps per second: 148, episode reward: -6048.201, mean reward: -3.661 [-2000.000, -0.074], mean action: 1.324 [0.000, 6.000],  loss: 3141.574884, mse: 31498.716640, mean_q: -172.864688, mean_eps: 0.067015
#  50011/100000: episode: 102, duration: 0.554s, episode steps:  80, steps per second: 144, episode reward: -2449.911, mean reward: -30.624 [-2000.000, -4.921], mean action: 0.163 [0.000, 6.000],  loss: 4229.683609, mse: 31902.134082, mean_q: -172.104178, mean_eps: 0.050574
#  52499/100000: episode: 103, duration: 16.980s, episode steps: 2488, steps per second: 147, episode reward: -11228.237, mean reward: -4.513 [-2000.000, -1.047], mean action: 0.842 [0.000, 6.000],  loss: 2981.570647, mse: 35362.393270, mean_q: -182.747843, mean_eps: 0.050000
#  52674/100000: episode: 104, duration: 1.213s, episode steps: 175, steps per second: 144, episode reward: -2536.406, mean reward: -14.494 [-2000.000, -1.548], mean action: 0.611 [0.000, 5.000],  loss: 3118.340545, mse: 37860.520781, mean_q: -189.180533, mean_eps: 0.050000
#  53044/100000: episode: 105, duration: 2.455s, episode steps: 370, steps per second: 151, episode reward: -3529.757, mean reward: -9.540 [-2000.000, -0.327], mean action: 1.251 [0.000, 6.000],  loss: 2800.881306, mse: 38542.819156, mean_q: -190.683202, mean_eps: 0.050000
#  53341/100000: episode: 106, duration: 1.986s, episode steps: 297, steps per second: 150, episode reward: -3160.455, mean reward: -10.641 [-2000.000, -1.443], mean action: 2.882 [0.000, 6.000],  loss: 2810.277590, mse: 39062.864636, mean_q: -192.135024, mean_eps: 0.050000
#  53699/100000: episode: 107, duration: 2.404s, episode steps: 358, steps per second: 149, episode reward: -3816.301, mean reward: -10.660 [-2000.000, -0.088], mean action: 0.162 [0.000, 6.000],  loss: 1467.081750, mse: 38286.710714, mean_q: -190.809215, mean_eps: 0.050000
#  53993/100000: episode: 108, duration: 1.986s, episode steps: 294, steps per second: 148, episode reward: -3073.073, mean reward: -10.453 [-2000.000, -1.344], mean action: 2.163 [0.000, 6.000],  loss: 2620.157965, mse: 39740.888313, mean_q: -194.449001, mean_eps: 0.050000
#  54482/100000: episode: 109, duration: 3.279s, episode steps: 489, steps per second: 149, episode reward: -3514.334, mean reward: -7.187 [-2000.000, -1.873], mean action: 2.182 [0.000, 6.000],  loss: 2832.691910, mse: 40049.019987, mean_q: -195.066885, mean_eps: 0.050000
#  54959/100000: episode: 110, duration: 3.163s, episode steps: 477, steps per second: 151, episode reward: -3512.861, mean reward: -7.364 [-2000.000, -0.930], mean action: 0.983 [0.000, 6.000],  loss: 2882.055182, mse: 40793.716666, mean_q: -196.099719, mean_eps: 0.050000
#  55933/100000: episode: 111, duration: 6.561s, episode steps: 974, steps per second: 148, episode reward: -6102.219, mean reward: -6.265 [-2000.000, -0.453], mean action: 1.004 [0.000, 6.000],  loss: 2356.756332, mse: 41374.466875, mean_q: -198.129032, mean_eps: 0.050000
#  56139/100000: episode: 112, duration: 1.392s, episode steps: 206, steps per second: 148, episode reward: -2807.085, mean reward: -13.627 [-2000.000, -1.892], mean action: 1.670 [0.000, 6.000],  loss: 2049.740165, mse: 41642.726800, mean_q: -199.008534, mean_eps: 0.050000
#  56619/100000: episode: 113, duration: 3.341s, episode steps: 480, steps per second: 144, episode reward: -3574.098, mean reward: -7.446 [-2000.000, -0.650], mean action: 2.148 [0.000, 6.000],  loss: 3032.060988, mse: 43346.517716, mean_q: -202.703071, mean_eps: 0.050000
#  56630/100000: episode: 114, duration: 0.120s, episode steps:  11, steps per second:  92, episode reward: -2055.797, mean reward: -186.891 [-2000.000, -4.749], mean action: 2.545 [2.000, 3.000],  loss: 4291.514090, mse: 48043.290661, mean_q: -211.008140, mean_eps: 0.050000
#  58023/100000: episode: 115, duration: 10.145s, episode steps: 1393, steps per second: 137, episode reward: -6949.149, mean reward: -4.989 [-2000.000, -0.234], mean action: 2.213 [0.000, 6.000],  loss: 2390.058104, mse: 44961.655644, mean_q: -205.918180, mean_eps: 0.050000
#  59140/100000: episode: 116, duration: 7.948s, episode steps: 1117, steps per second: 141, episode reward: -6989.184, mean reward: -6.257 [-2000.000, -0.395], mean action: 1.523 [0.000, 6.000],  loss: 2517.772065, mse: 47353.358415, mean_q: -211.891367, mean_eps: 0.050000
#  60290/100000: episode: 117, duration: 8.339s, episode steps: 1150, steps per second: 138, episode reward: -5575.174, mean reward: -4.848 [-2000.000, -0.468], mean action: 2.392 [0.000, 6.000],  loss: 2169.135885, mse: 48757.673961, mean_q: -214.569402, mean_eps: 0.050000
#  60543/100000: episode: 118, duration: 1.744s, episode steps: 253, steps per second: 145, episode reward: -2855.513, mean reward: -11.287 [-2000.000, -1.278], mean action: 1.186 [0.000, 6.000],  loss: 3328.678319, mse: 51413.611668, mean_q: -218.146200, mean_eps: 0.050000
#  61326/100000: episode: 119, duration: 5.317s, episode steps: 783, steps per second: 147, episode reward: -4578.811, mean reward: -5.848 [-2000.000, -0.157], mean action: 0.577 [0.000, 6.000],  loss: 2384.597043, mse: 51135.262639, mean_q: -217.240207, mean_eps: 0.050000
#  61908/100000: episode: 120, duration: 3.964s, episode steps: 582, steps per second: 147, episode reward: -4431.286, mean reward: -7.614 [-2000.000, -0.419], mean action: 0.112 [0.000, 6.000],  loss: 2822.830906, mse: 52201.909384, mean_q: -220.029938, mean_eps: 0.050000
#  61950/100000: episode: 121, duration: 0.281s, episode steps:  42, steps per second: 149, episode reward: -2195.550, mean reward: -52.275 [-2000.000, -4.443], mean action: 0.571 [0.000, 4.000],  loss: 1120.952671, mse: 51508.616257, mean_q: -219.542274, mean_eps: 0.050000
#  62153/100000: episode: 122, duration: 1.420s, episode steps: 203, steps per second: 143, episode reward: -3066.426, mean reward: -15.106 [-2000.000, -2.938], mean action: 0.123 [0.000, 6.000],  loss: 1394.234095, mse: 49781.913524, mean_q: -215.969973, mean_eps: 0.050000
#  62377/100000: episode: 123, duration: 1.562s, episode steps: 224, steps per second: 143, episode reward: -2854.613, mean reward: -12.744 [-2000.000, -1.074], mean action: 0.500 [0.000, 6.000],  loss: 2027.311965, mse: 51665.355338, mean_q: -219.788703, mean_eps: 0.050000
#  62390/100000: episode: 124, duration: 0.094s, episode steps:  13, steps per second: 138, episode reward: -2091.481, mean reward: -160.883 [-2000.000, -6.272], mean action: 0.154 [0.000, 1.000],  loss: 10968.209739, mse: 51920.829327, mean_q: -215.938472, mean_eps: 0.050000
#  62770/100000: episode: 125, duration: 2.579s, episode steps: 380, steps per second: 147, episode reward: -3295.729, mean reward: -8.673 [-2000.000, -0.042], mean action: 2.753 [0.000, 6.000],  loss: 2536.610786, mse: 53080.370600, mean_q: -223.096822, mean_eps: 0.050000
#  62803/100000: episode: 126, duration: 0.243s, episode steps:  33, steps per second: 136, episode reward: -2157.415, mean reward: -65.376 [-2000.000, -4.382], mean action: 0.061 [0.000, 2.000],  loss: 2720.164481, mse: 50065.950284, mean_q: -217.193379, mean_eps: 0.050000
#  63710/100000: episode: 127, duration: 6.299s, episode steps: 907, steps per second: 144, episode reward: -6608.091, mean reward: -7.286 [-2000.000, -1.091], mean action: 1.141 [0.000, 6.000],  loss: 2772.872829, mse: 54411.621161, mean_q: -224.203992, mean_eps: 0.050000
#  63832/100000: episode: 128, duration: 0.871s, episode steps: 122, steps per second: 140, episode reward: -2480.697, mean reward: -20.334 [-2000.000, -1.701], mean action: 1.041 [0.000, 6.000],  loss: 1935.793563, mse: 54550.168577, mean_q: -224.380828, mean_eps: 0.050000
#  63870/100000: episode: 129, duration: 0.275s, episode steps:  38, steps per second: 138, episode reward: -2200.687, mean reward: -57.913 [-2000.000, -4.448], mean action: 0.000 [0.000, 0.000],  loss: 25.584912, mse: 55248.639700, mean_q: -226.824400, mean_eps: 0.050000
#  64051/100000: episode: 130, duration: 1.250s, episode steps: 181, steps per second: 145, episode reward: -2944.118, mean reward: -16.266 [-2000.000, -3.673], mean action: 0.884 [0.000, 6.000],  loss: 1575.910362, mse: 53394.146409, mean_q: -223.303655, mean_eps: 0.050000
#  73180/100000: episode: 131, duration: 65.033s, episode steps: 9129, steps per second: 140, episode reward: -39554.208, mean reward: -4.333 [-2000.000, -0.170], mean action: 2.336 [0.000, 6.000],  loss: 2080.556966, mse: 60876.634182, mean_q: -235.523057, mean_eps: 0.050000
#  73501/100000: episode: 132, duration: 2.266s, episode steps: 321, steps per second: 142, episode reward: -2838.037, mean reward: -8.841 [-2000.000, -1.248], mean action: 1.660 [0.000, 6.000],  loss: 1888.295737, mse: 66871.081192, mean_q: -244.179326, mean_eps: 0.050000
#  73585/100000: episode: 133, duration: 0.580s, episode steps:  84, steps per second: 145, episode reward: -2364.015, mean reward: -28.143 [-2000.000, -2.691], mean action: 0.036 [0.000, 3.000],  loss: 28.879604, mse: 65204.081985, mean_q: -241.799890, mean_eps: 0.050000
#  77170/100000: episode: 134, duration: 25.693s, episode steps: 3585, steps per second: 140, episode reward: -11143.545, mean reward: -3.108 [-2000.000, -0.075], mean action: 2.688 [0.000, 6.000],  loss: 1772.702649, mse: 65698.114985, mean_q: -241.169169, mean_eps: 0.050000
#  80740/100000: episode: 135, duration: 25.830s, episode steps: 3570, steps per second: 138, episode reward: -14501.274, mean reward: -4.062 [-2000.000, -0.008], mean action: 2.457 [0.000, 6.000],  loss: 1660.371709, mse: 69827.510822, mean_q: -245.814669, mean_eps: 0.050000
#  90740/100000: episode: 136, duration: 73.981s, episode steps: 10000, steps per second: 135, episode reward: -35170.966, mean reward: -3.517 [-7.754, -0.049], mean action: 2.083 [0.000, 6.000],  loss: 1436.639377, mse: 76336.294008, mean_q: -253.281472, mean_eps: 0.050000
# done, took 630.788 seconds

# %% [markdown]
# ### 3.4 Saving the Model

# %% [markdown]
# When the training is finished, you can save the model that your DQN-agent has learned for later reuse, e.g. for evaluation or continued training. For this purpose, ```save_weights()``` is used.

# %%
weight_path = Path('saved_agents')
weight_path.mkdir(parents=True, exist_ok=True)
dqn.save_weights(str(weight_path / 'dqn_keras-RL2.hdf5'), overwrite=True)

# %% [markdown]
# ## 5. Evaluating an Agent

# %% [markdown]
# Keras-RL2 agents have their own ```test()``` method which can be used to evaluate their performance.
# Here, the metric used is the total reward the agent accumulates at the end of each episode.

# %% [markdown]
# ### 5.1 Loading a Model (Optional)

# %%
try:
    dqn.load_weights(str(weight_path / 'dqn_keras-RL2.hdf5'))
except OSError:
    print('Could not find model file. Continue')

# %% [markdown]
# ### 5.2 Testing

# %%
env.reset()
test_history = dqn.test(env,
                         nb_episodes=5,
                         nb_max_episode_steps=100000,
                         visualize=True
                         )
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -44281.266, steps: 10000
# Episode 2: reward: -31202.600, steps: 10000
# Episode 3: reward: -27821.012, steps: 10000
# Episode 4: reward: -24366.201, steps: 10000
# Episode 5: reward: -30157.671, steps: 10000
